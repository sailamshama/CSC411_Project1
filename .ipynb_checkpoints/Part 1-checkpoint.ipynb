# %%
'''
script won't run because image path does not exist on teaching lab computers
'''

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
x = np.load("x.npy")
y = np.load("y.npy")

# %%
names = np.unique(y)
locs = np.ones(6)
for i in range(names.shape[0]):
    locs[i] = np.where(y == names[i])[0][0]
# Out:
# [   0.  792.  173.  530.  672.  349.]

# %%
fig = plt.figure(figsize=(15, 10))

num1 = 109
a = fig.add_subplot(2,3,1)
img1 = x[:,:,num1]
a.set_title(y[num1])
plt.imshow(img1,cmap="gray")

num2 = 659
b = fig.add_subplot(2,3,2)
img2 =  x[:,:,num2]
b.set_title(y[num2])
plt.imshow(img2,cmap="gray")

num3 = 892
c = fig.add_subplot(2,3,3)
img3 = x[:,:,num3]
c.set_title("Angie Harmon")
plt.imshow(img3,cmap="gray")

###
d = fig.add_subplot(2,3,4)
img4 = plt.imread(os.path.join(os.getcwd(), "images",y[num1],y[num1]+"_unprocessed",y[num1]+"_"+str(num1)+".jpg"))
d.set_title(y[num1])
plt.imshow(img4,cmap="RdBu")

e = fig.add_subplot(2,3,5)
img5 = plt.imread(os.path.join(os.getcwd(), "images",y[num2],y[num2]+"_unprocessed",y[num2]+"_"+str(num2)+".jpg"))
e.set_title(y[num2])
plt.imshow(img5,cmap="RdBu")

f = fig.add_subplot(2,3,6)
img6 = plt.imread(os.path.join(os.getcwd(), "images",y[num3],y[num3]+"_unprocessed",y[num3]+"_"+str(num3)+".jpg"))
f.set_title(y[num3])
plt.imshow(img6)

plt.savefig("Figures_Part1_unusuals.pdf")

# %%
fig = plt.figure(figsize=(15, 10))

num4 = 20
g = fig.add_subplot(2,3,1)
img7 = x[:,:,num4]
g.set_title(y[num4])
plt.imshow(img7,cmap="gray")

num5 = 550
h = fig.add_subplot(2,3,2)
img8 =  x[:,:,num5]
h.set_title(y[num5])
plt.imshow(img8,cmap="gray")

num6 = 820
i = fig.add_subplot(2,3,3)
img9 = x[:,:,num6]
i.set_title("Angie Harmon")
plt.imshow(img9,cmap="gray")

###

j = fig.add_subplot(2,3,4)
img10 = plt.imread(os.path.join(os.getcwd(), "images",y[num4],y[num4]+"_unprocessed",y[num4]+"_"+str(num4)+".jpg"))
#j.set_title(y[num1])
plt.imshow(img10,cmap="RdBu")

k = fig.add_subplot(2,3,5)
img11 = plt.imread(os.path.join(os.getcwd(), "images",y[num5],y[num5]+"_unprocessed",y[num5]+"_"+str(num5)+".jpg"))
#k.set_title(y[num2])
plt.imshow(img11,cmap="RdBu")

l = fig.add_subplot(2,3,6)
img12 = plt.imread(os.path.join(os.getcwd(), "images",y[num6],y[num6]+"_unprocessed",y[num6]+"_"+str(num6)+".jpg"))
#l.set_title(y[num3])
plt.imshow(img12)

##################################################################################################################
plt.savefig("Figures_Part1_usuals.pdf")

# %%
fig = plt.figure(figsize=(15, 10))

num7 = 154
m = fig.add_subplot(2,3,1)
img13 = x[:,:,num7]
m.set_title(y[num7])
plt.imshow(img13,cmap="gray")

num8 = 660
m = fig.add_subplot(2,3,2)
img14 =  x[:,:,num8]
m.set_title(y[num8])
plt.imshow(img14,cmap="gray")

num9 = 920
o = fig.add_subplot(2,3,3)
img15 = x[:,:,num9]
o.set_title(y[num9])
plt.imshow(img15,cmap="gray")

####
p = fig.add_subplot(2,3,4)
img16 = plt.imread(os.path.join(os.getcwd(), "images",y[num7],y[num7]+"_unprocessed",y[num7]+"_"+str(num7)+".jpg"))
#p.set_title(y[num7])
plt.imshow(img16,cmap="RdBu")

q = fig.add_subplot(2,3,5)
img17 = plt.imread(os.path.join(os.getcwd(), "images",y[num8],y[num8]+"_unprocessed",y[num8]+"_"+str(num8)+".jpg"))
#q.set_title(y[num8])
plt.imshow(img17,cmap="RdBu")

r = fig.add_subplot(2,3,6)
img18 = plt.imread(os.path.join(os.getcwd(), "images",y[num9],y[num9]+"_unprocessed",y[num9]+"_"+str(num9)+".jpg"))
#r.set_title(y[num9])
plt.imshow(img18)
plt.savefig("Figures_Part1_tilt_and_bounding_box.pdf")
