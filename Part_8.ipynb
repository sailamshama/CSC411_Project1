# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#theta is n x k
#remoe theta0
theta = np.load("thetas_part7.npy")[1:]

# %%
np.array_equal(theta[:,1],theta[:,2])
# Out:
# False

# %%
fig = plt.figure()

a = fig.add_subplot(2,3,1)
img1 = theta[:,0].reshape(32,32)
a.set_title("Alec Baldwin")

b = fig.add_subplot(2,3,2)
img2 =  theta[:,1].reshape(32,32)
b.set_title("Angie Harmon")
plt.imshow(img2,cmap="RdBu")

c = fig.add_subplot(2,3,3)
img3 = theta[:,2].reshape(32,32)
c.set_title("Bill Hader")
plt.imshow(img3,cmap="RdBu")

d = fig.add_subplot(2,3,4)
img4 = theta[:,3].reshape(32,32)
d.set_title("Lorraine Bracco")
plt.imshow(img4,cmap="RdBu")

e = fig.add_subplot(2,3,5)
img5 = theta[:,4].reshape(32,32
e.set_title("Peri Gilpin")
plt.imshow(img5,cmap="RdBu")

f = fig.add_subplot(2,3,6)
img6 = plt.imshow( theta[:,5].reshape(32,32),  cmap="RdBu")
f.set_title("Steve Carell")
plt.imshow(img6,cmap="RdBu")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-37fe8a0ab9ea> in <module>()
#       8 img2 = plt.imshow( theta[:,1].reshape(32,32),  cmap="RdBu")
#       9 b.set_title("Angie Harmon")
# ---> 10 plt.imshow(img2,cmap="RdBu")
#      11
#      12 c = fig.add_subplot(2,3,3)
#
# /Users/Admin/anaconda3/envs/CSC411_py2_env/lib/python2.7/site-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3155                         filternorm=filternorm, filterrad=filterrad,
#    3156                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3157                         **kwargs)
#    3158     finally:
#    3159         ax._hold = washold
#
# /Users/Admin/anaconda3/envs/CSC411_py2_env/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /Users/Admin/anaconda3/envs/CSC411_py2_env/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5122                               resample=resample, **kwargs)
#    5123
# -> 5124         im.set_data(X)
#    5125         im.set_alpha(alpha)
#    5126         if im.get_clip_path() is None:
#
# /Users/Admin/anaconda3/envs/CSC411_py2_env/lib/python2.7/site-packages/matplotlib/image.pyc in set_data(self, A)
#     594         if (self._A.dtype != np.uint8 and
#     595                 not np.can_cast(self._A.dtype, np.float)):
# --> 596             raise TypeError("Image data can not convert to float")
#     597
#     598         if (self._A.ndim not in (2, 3) or
#
# TypeError: Image data can not convert to float
